# %%
name = "Zaeem Altaf"
age = 28
favorite_animal = "Horses"

print(f'My name is {name} and I am {age} years old and I love {favourite_animal}')

#

# Q#4 Write a program that demonstrates three different types of variables:
#
# A string (e.g., your favorite movie),
# An integer (e.g., your birth year), and
# A float (e.g., the price of your favorite snack).

favorite_movie = "Inception"

birth_year = 1998

favorite_snack_price = 2.99

# Display the values
print("Favorite Movie:", favorite_movie)
print("Birth Year:", birth_year)
print("Price of Favorite Snack: $", favorite_snack_price)

# Q#5 Create a variable called hobby and assign it a value (e.g., "reading books").

#Write a program that prints the sentence:

#My favorite hobby is [your hobby].
#Replace [your hobby] with the value of the hobby variable.


hobby = "reading books"

print("My favorite hobby is", hobby + ".")
